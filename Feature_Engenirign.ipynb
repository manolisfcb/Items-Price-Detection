# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv', )

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df
# Out:
#                   city             city_id condition  available_quantity  \
# 0        San Cristóbal    TUxBQlNBTjkwNTZa       new                   1
# 1         Buenos Aires    8d9b8743013d4f64      used                   1
# 2                Boedo    TUxBQkJPRTQ0OTRa      used                   1
# 3             Floresta    TUxBQkZMTzg5MjFa       new                   1
# 4      Tres de febrero  TUxBQ1RSRTMxODE5NA      used                   1
# ...                ...                 ...       ...                 ...
# 89995  capital federal    8d3afa99b1b943f6      used                   1
# 89996            Núñez    TUxBQk7a0TcwOTRa       new                   1
# 89997       La Matanza    TUxBQ0xBTWF0YW56       new                   1
# 89998           Trelew    f53026b2060743aa       new                 100
# 89999        mataderos    2522d6ea9f064164      used                   1
#
#          price  sold_quantity  free_shipping  local_pick_up  warranty  \
# ...

# %%
cities = df['city_id'].unique()
for city in cities:
    print(city)
# Out:
# TUxBQlNBTjkwNTZa
# 8d9b8743013d4f64
# TUxBQkJPRTQ0OTRa
# TUxBQkZMTzg5MjFa
# TUxBQ1RSRTMxODE5NA
# 6d775020da944fbc
# TUxBQkJBUjM0MDha
# c772ee961beb4f60
# 5647df925e064c87
# 0447d870c63245a9
# 7406be9fbccf4bfa
# TUxBQ0hVUmxpbmdo
# 2ad64477b72541a5
# a41d8df66f194457
# TUxBQ1JPUzg1Yjg3
# aeeecf24361c476a
# TUxBQk1PTjE2OTBa
# c21c276d90da4556
# 8723e7e7c4144786
# TUxBQ0VTQzQ3YTc0
# TUxBQkZMTzMwNzRa
# TUxBQ1NBTjg4ZmJk
# TUxBQlBBTDI1MTVa
# ba3aaf6516794587
# TUxBQkJBTDMxMDZa
# 0f68f80540154388
# TUxBQkJFTDcyNTJa
# TUxBQkNBQjM4MDda
# TUxBQlZJTDI3MDJa
# TUxBQlNBTjgzMjRa
# TUxBQlJFQzkyMTVa
# TUxBQ0FWRTc5OTQ1
# TUxBQ1RJRzk0ZjQw
# TUxBQlBBVDI0ODFa
# 406a3c96cb574155
# 8585b83001094ea4
# 3f2294023bb74792
# TUxBQ1NBTmMyZjY5
# 082dfc7d7f7b4d9b
# b0c47223b45d476a
# TUxBQlBBUjYwMzZa
# 3c471713a1fc4c28
# c395786ea1f84822
# c2be4d43b0cf4c35
# fde850c902204555
# e49b85710983418d
# TUxBQ0ZMTzYyNTZl
# 0597cace026f467d
# 7ed09a5d7edb4950
# a364edc274244155
# d47cbfa1590e449a
# TUxBQlNBTjgxMzNa
# ...

# %%
sort = df.sort_values(by='city')

# %%
for c in sort['city'].values:
    print(c)
# Out:
# (9103) Rawson
# (9103) Rawson
# (9103) Rawson
# (9103) Rawson
# (9103) Rawson
# (Buenos Aires) - La Matanza
# (Virreyes)
# (congreso)
# (v.crespo)
# (v.crespo)
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# -
# -
# -
# -
# .
# .
# ......
# 000
# 000
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1 cuadra de la estación de subte San Jose
# 1 cuadra de la estación de subte San Jose
# 1065
# 11 de setiembre
# 1104
# 1407
# 1419
# 1425
# 1425
# 1621
# 1621
# 1640
# 1669
# 1669
# 1686
# 1686
# 1702
# 1843
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 1er Junta - Caballito
# 2 de Abril
# 2000
# 25 de Mayo
# 25 de Mayo
# 25 de Mayo
# 25 de Mayo
# 25 de Mayo
# 25 de Mayo
# 3 DE FEBRERO
# 3 DE FEBRERO
# 3 DE FEBRERO
# 3 d febrero
# 3 de Febrero
# 3 de febrero
# 3 de febrero - Villa Bosch
# 3 febrero
# 500
# 6300
# 8 CUADRAS DE CAPITAL
# 9 de Abril
# 9 de Abril - Monte Grande
# ...
