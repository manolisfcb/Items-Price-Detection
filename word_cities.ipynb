# %%
import pandas as pd

# %%
world = pd.read_csv('worldcities.csv')

# %%
Argentina = world[world['country'] == 'Argentina']

# %%
Argentina
# Out:
#                       city           city_ascii      lat      lng    country  \
# 18            Buenos Aires         Buenos Aires -34.6033 -58.3817  Argentina
# 394                Córdoba              Cordoba -31.4167 -64.1833  Argentina
# 598                Rosario              Rosario -32.9575 -60.6394  Argentina
# 841    Santiago del Estero  Santiago del Estero -27.7833 -64.2667  Argentina
# 1021    Comodoro Rivadavia   Comodoro Rivadavia -45.8647 -67.4808  Argentina
# ...                    ...                  ...      ...      ...        ...
# 47410               Gastre               Gastre -42.2667 -69.2167  Argentina
# 47427               Telsen               Telsen -42.3833 -66.9500  Argentina
# 47481               Tandil               Tandil -37.3167 -59.1333  Argentina
# 47491            Rinconada            Rinconada -22.4333 -66.1667  Argentina
# 47585        Venado Tuerto        Venado Tuerto -33.7500 -61.9667  Argentina
#
# ...

# %%
Argentinas_cities = Argentina['admin_name'].unique()

# %%
Argentinas_cities
# Out:
# array(['Buenos Aires, Ciudad Autónoma de', 'Córdoba', 'Santa Fe',
#        'Santiago del Estero', 'Chubut', 'Buenos Aires', 'Tucumán',
#        'Salta', 'San Juan', 'Corrientes', 'Jujuy', 'Chaco', 'Misiones',
#        'Entre Ríos', 'Formosa', 'Neuquén', 'Mendoza', 'La Rioja',
#        'San Luis', 'Río Negro', 'Catamarca', 'La Pampa',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur',
#        'Santa Cruz'], dtype=object)
